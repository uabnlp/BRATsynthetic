# %%
# !nvidia-smi
# Out:
# Wed May 24 19:06:24 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 520.61.05    Driver Version: 520.61.05    CUDA Version: 11.8     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  On   | 00000000:04:00.0 Off |                    0 |
# | N/A   36C    P0    25W / 250W |      2MiB / 16384MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('/data/user/lateef11/bioNLP/OUD/data/v2.6/oud_2_6_2/conll/regex_removed/test.csv')

# %%
df.head(2)
# Out:
#       Token  Span  LineNum Label PHI_Label Substance_Label DocTimeRel  \
# 0  LANGFORD   1:9        2     O   PATIENT               O          O
# 1         ,  9:10        2     O   PATIENT               O          O
#
#   Negation Subject Uncertainity                           Path
# 0        O       O            O  \control\1047603\23177472.ann
# 1        O       O            O  \control\1047603\23177472.ann

# %%
df.PHI_Label.unique()
# Out:
# array(['PATIENT', 'O', 'AGE', 'HOSPITAL', 'DATE', 'DOCTOR',
#        'MEDICALRECORD', 'TIME', 'STREET', 'CITY', 'STATE', 'ZIP', 'PHONE',
#        'IDNUM', 'ORGANIZATION', 'USERNAME', 'PROFESSION', 'UNIQUE',
#        'HEALTHPLAN', 'LOCATION-OTHER'], dtype=object)

# %%
phi = ['PATIENT', 'AGE', 'HOSPITAL', 'DATE', 'DOCTOR','MEDICALRECORD', 'TIME', 
       'STREET', 'CITY', 'STATE', 'ZIP', 'PHONE','IDNUM', 'ORGANIZATION', 'USERNAME', 
       'PROFESSION', 'UNIQUE', 'HEALTHPLAN', 'LOCATION-OTHER']

# %% [markdown]
# # preprocess
# ### prepare train, dev, test dataframe from pipe dir.

# %%
# %%time
# consistent
# !python https://urldefense.com/v3/__http://preprocess_splitted_dir.py__;!!NoSwA-eRAg!HvZxOJTEwwu6rpphmPR-8g3gfuzxdNN8XjQ3VCkIq7fXo274C9UoUev0jffYxWASIazE9GCVLMSM1BmH0ps$
# Out:
# train_df.shape: (24190, 11)
# dev_df.shape: (2414, 11)
# test_df.shape: (1583, 11)
# Done pre-processing ...
# CPU times: user 482 ms, sys: 64 ms, total: 547 ms
# Wall time: 1min 6s

# %%
# %%time
# markov
# !python https://urldefense.com/v3/__http://preprocess_splitted_dir.py__;!!NoSwA-eRAg!HvZxOJTEwwu6rpphmPR-8g3gfuzxdNN8XjQ3VCkIq7fXo274C9UoUev0jffYxWASIazE9GCVLMSM1BmH0ps$
# Out:
# train_df.shape: (24210, 11)
# dev_df.shape: (2415, 11)
# test_df.shape: (1584, 11)
# Done pre-processing ...
# CPU times: user 452 ms, sys: 69.7 ms, total: 522 ms
# Wall time: 1min 4s

# %%
# %%time
# random
# !python https://urldefense.com/v3/__http://preprocess_splitted_dir.py__;!!NoSwA-eRAg!HvZxOJTEwwu6rpphmPR-8g3gfuzxdNN8XjQ3VCkIq7fXo274C9UoUev0jffYxWASIazE9GCVLMSM1BmH0ps$
# Out:
# train_df.shape: (24213, 11)
# dev_df.shape: (2415, 11)
# test_df.shape: (1586, 11)
# Done pre-processing ...
# CPU times: user 437 ms, sys: 64.8 ms, total: 502 ms
# Wall time: 1min 1s

# %%
# %%time
# simple
# !python https://urldefense.com/v3/__http://preprocess_splitted_dir.py__;!!NoSwA-eRAg!HvZxOJTEwwu6rpphmPR-8g3gfuzxdNN8XjQ3VCkIq7fXo274C9UoUev0jffYxWASIazE9GCVLMSM1BmH0ps$
# Out:
# train_df.shape: (24705, 11)
# dev_df.shape: (2506, 11)
# test_df.shape: (1616, 11)
# Done pre-processing ...
# CPU times: user 442 ms, sys: 72.7 ms, total: 514 ms
# Wall time: 1min 3s

# %%
# %%time
# original
# !python https://urldefense.com/v3/__http://preprocess_splitted_dir.py__;!!NoSwA-eRAg!HvZxOJTEwwu6rpphmPR-8g3gfuzxdNN8XjQ3VCkIq7fXo274C9UoUev0jffYxWASIazE9GCVLMSM1BmH0ps$
# Out:
# train_df.shape: (187688, 11)
# dev_df.shape: (21372, 11)
# test_df.shape: (20487, 11)
# Done pre-processing ...
# CPU times: user 458 ms, sys: 66 ms, total: 524 ms
# Wall time: 1min 4s

# %%
# %%time
# original
# !python https://urldefense.com/v3/__http://preprocess_splitted_dir.py__;!!NoSwA-eRAg!HvZxOJTEwwu6rpphmPR-8g3gfuzxdNN8XjQ3VCkIq7fXo274C9UoUev0jffYxWASIazE9GCVLMSM1BmH0ps$
# Out:
# train_df.shape: (24705, 11)
# dev_df.shape: (2506, 11)
# test_df.shape: (1616, 11)
# Done pre-processing ...
# CPU times: user 441 ms, sys: 73.3 ms, total: 515 ms
# Wall time: 1min 2s

# %%
original = 24705 + 2506 + 1616
consistent = 24190 + 2414 + 1583
markov = 24210 + 2415 + 1584
random = 24213 + 2415 + 1586
simple = 24705 + 2506 + 1616

# %%
print('original = ', original)
print('consistent = ', consistent)
print('markov = ', markov)
print('random = ', random)
print('simple = ', simple)
# Out:
# original =  28827
# consistent =  28187
# markov =  28209
# random =  28214
# simple =  28827

# %%
import joblib
df = joblib.load('synth_dir/original_train_df.bin')
# df = joblib.load('synth_dir/synth_random_train_df.bin')
# df = joblib.load('synth_dir/synth_consistent_train_df.bin')

# %%
df.head()
# Out:
#                                        text_file_name     entity_span  \
# 17  /data/user/lateef11/bioNLP/OUD/data/v2.6/oud_2...  [(1538, 1546)]
# 18  /data/user/lateef11/bioNLP/OUD/data/v2.6/oud_2...  [(1548, 1556)]
# 19  /data/user/lateef11/bioNLP/OUD/data/v2.6/oud_2...  [(2387, 2395)]
# 20  /data/user/lateef11/bioNLP/OUD/data/v2.6/oud_2...  [(2397, 2405)]
# 29  /data/user/lateef11/bioNLP/OUD/data/v2.6/oud_2...  [(2773, 2782)]
#
#                                               context             entity_type  \
# 17  - IV - Every 4 hr PRN (Other (see comment)) -1...                Fentanyl
# 18  ry 4 hr PRN (Other (see comment)) -180 day(s) ...                Fentanyl
# 19  mL/hr -IV Piggyback -Every 6 hr PRN (Other (se...  Buprenorphine-naloxone
# 20  Piggyback -Every 6 hr PRN (Other (see comment)...  Buprenorphine-naloxone
# 29  werNotes DOB: 11/09/1965 Page: 2 of 6 ADM: 01/...               Oxycodone
#
# ...

# %%
df = df[~df['entity_type'].isin(phi)]

# %%
df.head()
# Out:
#                                        text_file_name     entity_span  \
# 17  /data/user/lateef11/bioNLP/OUD/data/v2.6/oud_2...  [(1538, 1546)]
# 18  /data/user/lateef11/bioNLP/OUD/data/v2.6/oud_2...  [(1548, 1556)]
# 19  /data/user/lateef11/bioNLP/OUD/data/v2.6/oud_2...  [(2387, 2395)]
# 20  /data/user/lateef11/bioNLP/OUD/data/v2.6/oud_2...  [(2397, 2405)]
# 29  /data/user/lateef11/bioNLP/OUD/data/v2.6/oud_2...  [(2773, 2782)]
#
#                                               context             entity_type  \
# 17  - IV - Every 4 hr PRN (Other (see comment)) -1...                Fentanyl
# 18  ry 4 hr PRN (Other (see comment)) -180 day(s) ...                Fentanyl
# 19  mL/hr -IV Piggyback -Every 6 hr PRN (Other (se...  Buprenorphine-naloxone
# 20  Piggyback -Every 6 hr PRN (Other (see comment)...  Buprenorphine-naloxone
# 29  werNotes DOB: 11/09/1965 Page: 2 of 6 ADM: 01/...               Oxycodone
#
# ...

# %%
labelEncoder_meta_data = joblib.load("synth_dir/original_oud_meta.bin")

# %%
labelEncoder_meta_data['negation'].classes_, labelEncoder_meta_data['subject'].classes_
# Out:
# (array(['False', 'True'], dtype=object),
#  array(['FamilyMember', 'Patient'], dtype=object))

# %%
for k in df.keys():
    if k == 'negation' or k=='doctime' or k=='uncertainty' or k=='severity' or k=='illicitDrugUse' or k=='subject':
        print(k)
        print(df[k].value_counts())
        print('------------\n')
    else:
        continue
# Out:
# negation
# 0    22976
# 1     1729
# Name: negation, dtype: int64
# ------------
#
# doctime
# 2    22827
# 1     1405
# 0      473
# Name: doctime, dtype: int64
# ------------
#
# uncertainty
# 0    24602
# 1      103
# Name: uncertainty, dtype: int64
# ------------
#
# severity
# 0    24705
# Name: severity, dtype: int64
# ------------
#
# illicitDrugUse
# 0    24705
# Name: illicitDrugUse, dtype: int64
# ------------
#
# subject
# 1    24283
# 0      422
# Name: subject, dtype: int64
# ------------

# %% [markdown]
# # Train and Predict

# %%
# %%time
# synth_dir/original
# !python https://urldefense.com/v3/__http://train.py__;!!NoSwA-eRAg!HvZxOJTEwwu6rpphmPR-8g3gfuzxdNN8XjQ3VCkIq7fXo274C9UoUev0jffYxWASIazE9GCVLMSMRiRW1cs$
# Out:
# 773
# cuda:0
# total epochs: 3
# total_steps: 2319
# EPOCH 1/3
# 100%|█████████████████████████████████████████| 773/773 [05:09<00:00,  2.50it/s]
# Traceback (most recent call last):
#   File "train.py", line 81, in <module>
#     device, scheduler, len(train_df)#, weight_dict
#   File "/data/user/lateef11/bioNLP/OUD/modifiers/new_modifiers/utils.py", line 54, in train_fn
#     return accuracies[0], accuracies[1], accuracies[2], accuracies[3], final_loss/len(data_loader)
# IndexError: index 3 is out of bounds for axis 0 with size 3
# CPU times: user 2.21 s, sys: 482 ms, total: 2.69 s
# Wall time: 5min 52s

# %%
# %%time
# synth_dir/original
# !python https://urldefense.com/v3/__http://train.py__;!!NoSwA-eRAg!HvZxOJTEwwu6rpphmPR-8g3gfuzxdNN8XjQ3VCkIq7fXo274C9UoUev0jffYxWASIazE9GCVLMSMRiRW1cs$  \
-b 128 -e 2 -m bio_bert
# Out:
# 194
# cuda:0
# total epochs: 2
# total_steps: 388
# EPOCH 1/2
# ...
# 100%|█████████████████████████████████████████| 157/157 [00:11<00:00, 14.18it/s]
# Train Loss = 0.070918265307687 Valid Loss = 0.03343732286078535
# Train accuracy <Neg>= 0.9668893218040466 Valid accuracy <Neg>= 0.9860335195530726
# Train accuracy <doctime>= 0.9178304076194763 Valid accuracy <doctime>= 0.9473264166001596
# Train accuracy <subject>= 0.9848209023475647 Valid accuracy <subject>= 0.9916201117318436
# saving model ...
# EPOCH 2/2
# ...
# 100%|█████████████████████████████████████████| 157/157 [00:11<00:00, 14.19it/s]
# Train Loss = 0.029521325571323295 Valid Loss = 0.0271194284525255
# Train accuracy <Neg>= 0.9877757430076599 Valid accuracy <Neg>= 0.990023942537909
# Train accuracy <doctime>= 0.9619510173797607 Valid accuracy <doctime>= 0.9581005586592178
# Train accuracy <subject>= 0.9933211803436279 Valid accuracy <subject>= 0.9960095770151636
# saving model ...
# ...

# %%
# %%time
# synth_dir/original
# !python https://urldefense.com/v3/__http://train.py__;!!NoSwA-eRAg!HvZxOJTEwwu6rpphmPR-8g3gfuzxdNN8XjQ3VCkIq7fXo274C9UoUev0jffYxWASIazE9GCVLMSMRiRW1cs$  \
-b 128 -e 2 -m bert
# Out:
# 194
# cuda:0
# total epochs: 2
# total_steps: 388
# EPOCH 1/2
# ...
# 100%|█████████████████████████████████████████| 157/157 [00:11<00:00, 14.20it/s]
# Train Loss = 0.0726816791491391 Valid Loss = 0.03429748745231777
# Train accuracy <Neg>= 0.9560412764549255 Valid accuracy <Neg>= 0.9848363926576217
# Train accuracy <doctime>= 0.92560213804245 Valid accuracy <doctime>= 0.9565043894652833
# Train accuracy <subject>= 0.9838089346885681 Valid accuracy <subject>= 0.9892258579409418
# saving model ...
# EPOCH 2/2
# ...
# 100%|█████████████████████████████████████████| 157/157 [00:11<00:00, 14.19it/s]
# Train Loss = 0.02984469245936837 Valid Loss = 0.02679360762555864
# Train accuracy <Neg>= 0.9877757430076599 Valid accuracy <Neg>= 0.9896249002394254
# Train accuracy <doctime>= 0.9612629413604736 Valid accuracy <doctime>= 0.9632881085395052
# Train accuracy <subject>= 0.9921877980232239 Valid accuracy <subject>= 0.9936153232242618
# saving model ...
# ...

# %%
# %%time
# synth_dir/original
# !python https://urldefense.com/v3/__http://train.py__;!!NoSwA-eRAg!HvZxOJTEwwu6rpphmPR-8g3gfuzxdNN8XjQ3VCkIq7fXo274C9UoUev0jffYxWASIazE9GCVLMSMRiRW1cs$  \
-b 128 -e 4 -m bio_bert
# Out:
# 194
# cuda:0
# total epochs: 4
# total_steps: 776
# EPOCH 1/4
# ...
# 100%|█████████████████████████████████████████| 157/157 [00:11<00:00, 14.21it/s]
# Train Loss = 0.08202461568523467 Valid Loss = 0.035428910126174044
# Train accuracy <Neg>= 0.9519125819206238 Valid accuracy <Neg>= 0.9876296887470072
# Train accuracy <doctime>= 0.9195709228515625 Valid accuracy <doctime>= 0.946927374301676
# Train accuracy <subject>= 0.9723537564277649 Valid accuracy <subject>= 0.9864325618515563
# saving model ...
# EPOCH 2/4
# ...
# 100%|█████████████████████████████████████████| 157/157 [00:11<00:00, 14.21it/s]
# Train Loss = 0.031749070465706346 Valid Loss = 0.025283022535294533
# Train accuracy <Neg>= 0.9855090379714966 Valid accuracy <Neg>= 0.990023942537909
# Train accuracy <doctime>= 0.959117591381073 Valid accuracy <doctime>= 0.9652833200319234
# Train accuracy <subject>= 0.9883829355239868 Valid accuracy <subject>= 0.9924181963288109
# saving model ...
# EPOCH 3/4
# ...

# %%
# %%time
# !python https://urldefense.com/v3/__http://predict.py__;!!NoSwA-eRAg!HvZxOJTEwwu6rpphmPR-8g3gfuzxdNN8XjQ3VCkIq7fXo274C9UoUev0jffYxWASIazE9GCVLMSMfba8HEw$  \
-vb 64 -m bio_bert \
-c https://urldefense.com/v3/__http://oud_modifires_model.pt_epoch3.pt__;!!NoSwA-eRAg!HvZxOJTEwwu6rpphmPR-8g3gfuzxdNN8XjQ3VCkIq7fXo274C9UoUev0jffYxWASIazE9GCVLMSMMdiwjnY$
# Out:
# oud_modifires_model.pt_epoch3.pt
# 100%|█████████████████████████████████████████| 387/387 [01:42<00:00,  3.78it/s]
# negation Report:
#               precision    recall  f1-score   support
#
#        False     0.9966    0.9956    0.9961     23000
#         True     0.9416    0.9548    0.9482      1705
#
#     accuracy                         0.9928     24705
#    macro avg     0.9691    0.9752    0.9721     24705
# weighted avg     0.9928    0.9928    0.9928     24705
#
# ----------------------------------------------------------------------------------------------------
# doctime Report:
#               precision    recall  f1-score   support
#
#        After     0.9471    0.9143    0.9304       490
#       Before     0.8434    0.9080    0.8745      1305
#      Overlap     0.9933    0.9897    0.9915     22910
#
#     accuracy                         0.9839     24705
#    macro avg     0.9280    0.9373    0.9322     24705
# weighted avg     0.9845    0.9839    0.9841     24705
#
# ...

# %%
# %%time
# synth_dir/synth_consistent
# !python https://urldefense.com/v3/__http://train.py__;!!NoSwA-eRAg!HvZxOJTEwwu6rpphmPR-8g3gfuzxdNN8XjQ3VCkIq7fXo274C9UoUev0jffYxWASIazE9GCVLMSMRiRW1cs$  \
-d synth_dir/synth_consistent \
-b 128 -e 4 -m bio_bert
# Out:
# synth_dir/synth_consistent
# 189
# cuda:0
# total epochs: 4
# total_steps: 756
# EPOCH 1/4
# ...
# 100%|█████████████████████████████████████████| 151/151 [00:10<00:00, 14.15it/s]
# Train Loss = 0.0812581043651022 Valid Loss = 0.03670343064505681
# Train accuracy <Neg>= 0.9579578638076782 Valid accuracy <Neg>= 0.9884009942004971
# Train accuracy <doctime>= 0.9245555996894836 Valid accuracy <doctime>= 0.9465617232808616
# Train accuracy <subject>= 0.9784208536148071 Valid accuracy <subject>= 0.9875724937862469
# saving model ...
# EPOCH 2/4
# ...
# 100%|█████████████████████████████████████████| 151/151 [00:10<00:00, 14.16it/s]
# Train Loss = 0.031474631033325325 Valid Loss = 0.02682551173246558
# Train accuracy <Neg>= 0.986647367477417 Valid accuracy <Neg>= 0.9896437448218725
# Train accuracy <doctime>= 0.9580819010734558 Valid accuracy <doctime>= 0.9614747307373653
# Train accuracy <subject>= 0.9921869039535522 Valid accuracy <subject>= 0.9946147473073736
# saving model ...
# EPOCH 3/4
# ...

# %%
# %%time
# !python https://urldefense.com/v3/__http://predict.py__;!!NoSwA-eRAg!HvZxOJTEwwu6rpphmPR-8g3gfuzxdNN8XjQ3VCkIq7fXo274C9UoUev0jffYxWASIazE9GCVLMSMfba8HEw$  \
-d synth_dir/synth_consistent \
-vb 64 -m bio_bert \
-c synth_dir/https://urldefense.com/v3/__http://synth_consistent_oud_modifires_model.pt_epoch3.pt__;!!NoSwA-eRAg!HvZxOJTEwwu6rpphmPR-8g3gfuzxdNN8XjQ3VCkIq7fXo274C9UoUev0jffYxWASIazE9GCVLMSMs6Dl6r4$
# Out:
# synth_dir/synth_consistent_oud_modifires_model.pt_epoch3.pt
# 100%|█████████████████████████████████████████| 378/378 [01:39<00:00,  3.78it/s]
# negation Report:
#               precision    recall  f1-score   support
#
#        False     0.9966    0.9964    0.9965     22474
#         True     0.9529    0.9551    0.9540      1716
#
#     accuracy                         0.9935     24190
#    macro avg     0.9747    0.9758    0.9753     24190
# weighted avg     0.9935    0.9935    0.9935     24190
#
# ----------------------------------------------------------------------------------------------------
# doctime Report:
#               precision    recall  f1-score   support
#
#        After     0.9002    0.9263    0.9131       448
#       Before     0.8176    0.9295    0.8700      1177
#      Overlap     0.9954    0.9877    0.9915     22565
#
#     accuracy                         0.9837     24190
#    macro avg     0.9044    0.9478    0.9249     24190
# ...

# %%
# %%time
# synth_dir/synth_markov
# !python https://urldefense.com/v3/__http://train.py__;!!NoSwA-eRAg!HvZxOJTEwwu6rpphmPR-8g3gfuzxdNN8XjQ3VCkIq7fXo274C9UoUev0jffYxWASIazE9GCVLMSMRiRW1cs$  \
-d synth_dir/synth_markov \
-b 128 -e 4 -m bio_bert
# Out:
# synth_dir/synth_markov
# 190
# cuda:0
# total epochs: 4
# total_steps: 760
# EPOCH 1/4
# ...
# 100%|█████████████████████████████████████████| 151/151 [00:10<00:00, 14.18it/s]
# Train Loss = 0.08290084063222533 Valid Loss = 0.03946021992392493
# Train accuracy <Neg>= 0.9577034711837769 Valid accuracy <Neg>= 0.9892339544513458
# Train accuracy <doctime>= 0.9251962304115295 Valid accuracy <doctime>= 0.9445134575569358
# Train accuracy <subject>= 0.9804213643074036 Valid accuracy <subject>= 0.9855072463768116
# saving model ...
# EPOCH 2/4
# ...
# 100%|█████████████████████████████████████████| 151/151 [00:10<00:00, 14.19it/s]
# Train Loss = 0.03384200078925412 Valid Loss = 0.02583060265497138
# Train accuracy <Neg>= 0.9863280057907104 Valid accuracy <Neg>= 0.9888198757763975
# Train accuracy <doctime>= 0.9526642560958862 Valid accuracy <doctime>= 0.9627329192546584
# Train accuracy <subject>= 0.9893845915794373 Valid accuracy <subject>= 0.9925465838509316
# saving model ...
# EPOCH 3/4
# ...

# %%
# %%time
# !python https://urldefense.com/v3/__http://predict.py__;!!NoSwA-eRAg!HvZxOJTEwwu6rpphmPR-8g3gfuzxdNN8XjQ3VCkIq7fXo274C9UoUev0jffYxWASIazE9GCVLMSMfba8HEw$  \
-d synth_dir/synth_markov \
-vb 64 -m bio_bert \
-c synth_dir/https://urldefense.com/v3/__http://synth_markov_oud_modifires_model.pt_epoch3.pt__;!!NoSwA-eRAg!HvZxOJTEwwu6rpphmPR-8g3gfuzxdNN8XjQ3VCkIq7fXo274C9UoUev0jffYxWASIazE9GCVLMSMEEqBN6k$
# Out:
# synth_dir/synth_markov_oud_modifires_model.pt_epoch3.pt
# 100%|█████████████████████████████████████████| 379/379 [01:40<00:00,  3.79it/s]
# negation Report:
#               precision    recall  f1-score   support
#
#        False     0.9965    0.9956    0.9960     22507
#         True     0.9420    0.9542    0.9481      1703
#
#     accuracy                         0.9926     24210
#    macro avg     0.9693    0.9749    0.9721     24210
# weighted avg     0.9927    0.9926    0.9927     24210
#
# ----------------------------------------------------------------------------------------------------
# doctime Report:
#               precision    recall  f1-score   support
#
#        After     0.9414    0.8893    0.9146       488
#       Before     0.8277    0.9127    0.8681      1226
#      Overlap     0.9935    0.9891    0.9913     22496
#
#     accuracy                         0.9832     24210
#    macro avg     0.9209    0.9304    0.9247     24210
# ...

# %%
# %%time
# synth_dir/synth_random
# !python https://urldefense.com/v3/__http://train.py__;!!NoSwA-eRAg!HvZxOJTEwwu6rpphmPR-8g3gfuzxdNN8XjQ3VCkIq7fXo274C9UoUev0jffYxWASIazE9GCVLMSMRiRW1cs$  \
-d synth_dir/synth_random \
-b 128 -e 4 -m bio_bert
# Out:
# synth_dir/synth_random
# 190
# cuda:0
# total epochs: 4
# total_steps: 760
# EPOCH 1/4
# ...
# 100%|█████████████████████████████████████████| 151/151 [00:10<00:00, 14.19it/s]
# Train Loss = 0.0736728715465257 Valid Loss = 0.03673114225157345
# Train accuracy <Neg>= 0.9640275835990906 Valid accuracy <Neg>= 0.9888198757763975
# Train accuracy <doctime>= 0.9273117780685425 Valid accuracy <doctime>= 0.9457556935817806
# Train accuracy <subject>= 0.9767067432403564 Valid accuracy <subject>= 0.991304347826087
# saving model ...
# EPOCH 2/4
# ...
# 100%|█████████████████████████████████████████| 151/151 [00:10<00:00, 14.18it/s]
# Train Loss = 0.03064441744140104 Valid Loss = 0.026660561560042546
# Train accuracy <Neg>= 0.9868252873420715 Valid accuracy <Neg>= 0.989648033126294
# Train accuracy <doctime>= 0.9598975777626038 Valid accuracy <doctime>= 0.9585921325051759
# Train accuracy <subject>= 0.9925246834754944 Valid accuracy <subject>= 0.9937888198757764
# saving model ...
# EPOCH 3/4
# ...

# %%
# %%time
# !python https://urldefense.com/v3/__http://predict.py__;!!NoSwA-eRAg!HvZxOJTEwwu6rpphmPR-8g3gfuzxdNN8XjQ3VCkIq7fXo274C9UoUev0jffYxWASIazE9GCVLMSMfba8HEw$  \
-d synth_dir/synth_random \
-vb 64 -m bio_bert \
-c synth_dir/https://urldefense.com/v3/__http://synth_random_oud_modifires_model.pt_epoch3.pt__;!!NoSwA-eRAg!HvZxOJTEwwu6rpphmPR-8g3gfuzxdNN8XjQ3VCkIq7fXo274C9UoUev0jffYxWASIazE9GCVLMSM8MOoNvs$
# Out:
# synth_dir/synth_random_oud_modifires_model.pt_epoch3.pt
# 100%|█████████████████████████████████████████| 379/379 [01:40<00:00,  3.78it/s]
# negation Report:
#               precision    recall  f1-score   support
#
#        False     0.9971    0.9958    0.9964     22521
#         True     0.9448    0.9616    0.9531      1692
#
#     accuracy                         0.9934     24213
#    macro avg     0.9710    0.9787    0.9748     24213
# weighted avg     0.9935    0.9934    0.9934     24213
#
# ----------------------------------------------------------------------------------------------------
# doctime Report:
#               precision    recall  f1-score   support
#
#        After     0.9413    0.9193    0.9302       471
#       Before     0.8407    0.9241    0.8804      1239
#      Overlap     0.9947    0.9897    0.9922     22503
#
#     accuracy                         0.9850     24213
#    macro avg     0.9256    0.9444    0.9343     24213
# ...

# %%
# %%time
# synth_dir/synth_simple
# !python https://urldefense.com/v3/__http://train.py__;!!NoSwA-eRAg!HvZxOJTEwwu6rpphmPR-8g3gfuzxdNN8XjQ3VCkIq7fXo274C9UoUev0jffYxWASIazE9GCVLMSMRiRW1cs$  \
-d synth_dir/synth_simple \
-b 128 -e 4 -m bio_bert
# Out:
# synth_dir/synth_simple
# 194
# cuda:0
# total epochs: 4
# total_steps: 776
# EPOCH 1/4
# ...
# 100%|█████████████████████████████████████████| 157/157 [00:11<00:00, 14.19it/s]
# Train Loss = 0.06339525682467621 Valid Loss = 0.02740466744478816
# Train accuracy <Neg>= 0.9687107801437378 Valid accuracy <Neg>= 0.9896249002394254
# Train accuracy <doctime>= 0.9315118193626404 Valid accuracy <doctime>= 0.9581005586592178
# Train accuracy <subject>= 0.9849827885627747 Valid accuracy <subject>= 0.9920191540303273
# saving model ...
# EPOCH 2/4
# ...
# 100%|█████████████████████████████████████████| 157/157 [00:11<00:00, 14.19it/s]
# Train Loss = 0.025480377670862357 Valid Loss = 0.022524688935283997
# Train accuracy <Neg>= 0.9879781603813171 Valid accuracy <Neg>= 0.9908220271348763
# Train accuracy <doctime>= 0.968913197517395 Valid accuracy <doctime>= 0.9632881085395052
# Train accuracy <subject>= 0.9927545189857483 Valid accuracy <subject>= 0.9960095770151636
# saving model ...
# EPOCH 3/4
# ...

# %%
# %%time
# !python https://urldefense.com/v3/__http://predict.py__;!!NoSwA-eRAg!HvZxOJTEwwu6rpphmPR-8g3gfuzxdNN8XjQ3VCkIq7fXo274C9UoUev0jffYxWASIazE9GCVLMSMfba8HEw$  \
-d synth_dir/synth_simple \
-vb 64 -m bio_bert \
-c synth_dir/https://urldefense.com/v3/__http://synth_simple_oud_modifires_model.pt_epoch2.pt__;!!NoSwA-eRAg!HvZxOJTEwwu6rpphmPR-8g3gfuzxdNN8XjQ3VCkIq7fXo274C9UoUev0jffYxWASIazE9GCVLMSMZAmTv5A$
# Out:
# synth_dir/synth_simple_oud_modifires_model.pt_epoch2.pt
# 100%|█████████████████████████████████████████| 387/387 [01:42<00:00,  3.79it/s]
# negation Report:
#               precision    recall  f1-score   support
#
#        False     0.9968    0.9946    0.9957     23027
#         True     0.9277    0.9559    0.9416      1678
#
#     accuracy                         0.9919     24705
#    macro avg     0.9622    0.9752    0.9686     24705
# weighted avg     0.9921    0.9919    0.9920     24705
#
# ----------------------------------------------------------------------------------------------------
# doctime Report:
#               precision    recall  f1-score   support
#
#        After     0.9049    0.9264    0.9155       462
#       Before     0.8391    0.9055    0.8711      1302
#      Overlap     0.9935    0.9885    0.9910     22941
#
#     accuracy                         0.9830     24705
#    macro avg     0.9125    0.9402    0.9259     24705
# ...
